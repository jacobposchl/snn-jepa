# %%
# !rm -rf snn-jepa
# !git clone https://github.com/jacobposchl/snn-jepa
# %cd snn-jepa

# %%
import os
from google.colab import drive

# Mount Google Drive
print("Mounting Drive...")
drive.mount('/content/drive')

# Paths for data
ZIP_PATH = "/content/drive/MyDrive/SNN-LeJEPA/Data/Preprocessed/processed.zip"
LOCAL_DEST = "/content/preprocessed_data"

# unzip data
if os.path.exists(ZIP_PATH):
    os.makedirs(LOCAL_DEST, exist_ok=True)
    print(f"✅ Found file. Unzipping to local SSD...")
    # !unzip -q "{ZIP_PATH}" -d "{LOCAL_DEST}"
    print("🚀 Done. Data available at /content/preprocessed_data/processed.pkl")
else:
    print(f"❌ ERROR: File not found at {ZIP_PATH}")
    print("Please ensure your Drive has the folder: SNN-LeJEPA/Data/Preprocessed/")

# Final verification of the .pkl
# !ls -lh {LOCAL_DEST}

# %%
# Launch the Tunnel
# !curl -Lk 'https://code.visualstudio.com/sha/download?build=stable&os=cli-alpine-x64' --output vscode_cli.tar.gz
# !tar -xf vscode_cli.tar.gz
# !./code tunnel
